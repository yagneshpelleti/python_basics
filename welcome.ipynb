# %% [markdown]
# <a href="https://colab.research.google.com/github/yagneshpelleti/python_basics/blob/main/welcome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to python")
# Out:
# welcome to python
