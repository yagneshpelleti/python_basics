# %% [markdown]
# <a href="https://colab.research.google.com/github/yagneshpelleti/python_basics/blob/main/logical_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(5>6 and 6>8)
# Out:
# False

# %%
print(6<8 or 9>10)
# Out:
# True

# %%
print(not 5>4)
# Out:
# False
