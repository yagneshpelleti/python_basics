# %% [markdown]
# <a href="https://colab.research.google.com/github/yagneshpelleti/python_basics/blob/main/multiplication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=348
b=565
c=a*b
print(c)
# Out:
# 196620
